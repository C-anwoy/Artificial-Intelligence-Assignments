# %% [markdown]
# # Assignment 3 - Logistic Regression
#
# Given the marks of a student in two subjects we want to predict whether he will get admission or not.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from model import *
from utils import *

# %%
file = 'marks.csv'

# %%
X, Y, admitted, not_admitted = load_data(file)

# %% [markdown]
# ### Visualize dataset

# %%
visualize_data(admitted, not_admitted)

# %% [markdown]
# ### Train the model

# %%
# Try changing the learning rate and number of iterations

##################
lr = 10**(-4)
num_iter = 10000
##################

model = LogisticRegression() 
model.train(X, Y, lr,num_iter,50)
print("Model Accuracy: {}".format(model.accuracy(X,Y)))
# Out:
# Iteration 0 of 10000. Loss: 0.693147 LR: 0.000100
# Iteration 200 of 10000. Loss: 0.629803 LR: 0.000100
# Iteration 400 of 10000. Loss: 0.629629 LR: 0.000100
# Iteration 600 of 10000. Loss: 0.629529 LR: 0.000100
# Iteration 800 of 10000. Loss: 0.629431 LR: 0.000100
# Iteration 1000 of 10000. Loss: 0.629334 LR: 0.000100
# Iteration 1200 of 10000. Loss: 0.629237 LR: 0.000100
# Iteration 1400 of 10000. Loss: 0.629139 LR: 0.000100
# Iteration 1600 of 10000. Loss: 0.629042 LR: 0.000100
# Iteration 1800 of 10000. Loss: 0.628945 LR: 0.000100
# Iteration 2000 of 10000. Loss: 0.628847 LR: 0.000100
# Iteration 2200 of 10000. Loss: 0.628750 LR: 0.000100
# Iteration 2400 of 10000. Loss: 0.628653 LR: 0.000100
# Iteration 2600 of 10000. Loss: 0.628556 LR: 0.000100
# Iteration 2800 of 10000. Loss: 0.628459 LR: 0.000100
# Iteration 3000 of 10000. Loss: 0.628362 LR: 0.000100
# Iteration 3200 of 10000. Loss: 0.628265 LR: 0.000100
# Iteration 3400 of 10000. Loss: 0.628168 LR: 0.000100
# Iteration 3600 of 10000. Loss: 0.628071 LR: 0.000100
# Iteration 3800 of 10000. Loss: 0.627974 LR: 0.000100
# Iteration 4000 of 10000. Loss: 0.627877 LR: 0.000100
# Iteration 4200 of 10000. Loss: 0.627780 LR: 0.000100
# Iteration 4400 of 10000. Loss: 0.627684 LR: 0.000100
# Iteration 4600 of 10000. Loss: 0.627587 LR: 0.000100
# Iteration 4800 of 10000. Loss: 0.627490 LR: 0.000100
# Iteration 5000 of 10000. Loss: 0.627393 LR: 0.000100
# Iteration 5200 of 10000. Loss: 0.627297 LR: 0.000100
# Iteration 5400 of 10000. Loss: 0.627200 LR: 0.000100
# Iteration 5600 of 10000. Loss: 0.627103 LR: 0.000100
# Iteration 5800 of 10000. Loss: 0.627007 LR: 0.000100
# Iteration 6000 of 10000. Loss: 0.626910 LR: 0.000100
# Iteration 6200 of 10000. Loss: 0.626814 LR: 0.000100
# Iteration 6400 of 10000. Loss: 0.626717 LR: 0.000100
# Iteration 6600 of 10000. Loss: 0.626621 LR: 0.000100
# Iteration 6800 of 10000. Loss: 0.626524 LR: 0.000100
# Iteration 7000 of 10000. Loss: 0.626428 LR: 0.000100
# Iteration 7200 of 10000. Loss: 0.626332 LR: 0.000100
# Iteration 7400 of 10000. Loss: 0.626235 LR: 0.000100
# Iteration 7600 of 10000. Loss: 0.626139 LR: 0.000100
# Iteration 7800 of 10000. Loss: 0.626043 LR: 0.000100
# Iteration 8000 of 10000. Loss: 0.625947 LR: 0.000100
# Iteration 8200 of 10000. Loss: 0.625850 LR: 0.000100
# Iteration 8400 of 10000. Loss: 0.625754 LR: 0.000100
# Iteration 8600 of 10000. Loss: 0.625658 LR: 0.000100
# Iteration 8800 of 10000. Loss: 0.625562 LR: 0.000100
# Iteration 9000 of 10000. Loss: 0.625466 LR: 0.000100
# Iteration 9200 of 10000. Loss: 0.625370 LR: 0.000100
# Iteration 9400 of 10000. Loss: 0.625274 LR: 0.000100
# Iteration 9600 of 10000. Loss: 0.625178 LR: 0.000100
# Iteration 9800 of 10000. Loss: 0.625082 LR: 0.000100
# Model Accuracy: 0.6

# %% [markdown]
# ### Visualize Decision Boundary

# %%
visualize_decision_boundary(admitted, not_admitted, X, model.weights.flatten())

# %% [markdown]
# ### Save hyperparameters

# %%
save_hyperparameters(lr, num_iter)
